# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandramcrs08/DataVisualization/blob/main/DataVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Exercício Prático - Data Visualization

# %% [markdown]
# **Desafio Prático 1: Visualizando Dados Diferentes**
#
# **Descrição:** Neste desafio, suas alunas irão visualizar dados de diferentes formas utilizando
# Matplotlib, Seaborn e Plotly. Elas deverão criar gráficos que mostrem a distribuição dos
# dados, correlações entre variáveis e tendências.
#
#
# **Tarefas:**

# %% [markdown]
# 1. Carregar os dados de um arquivo CSV fornecido (saude.csv).

# %%
import pandas as pd

# Carregar o arquivo CSV
df_saude = pd.read_csv('/content/drive/MyDrive/saude.csv')

# Verificar as primeiras linhas do DataFrame
print(df_saude.head())
# Out:
#    id  age  height  weight gender
# 0   1   23     170      70      M
# 1   2   34     160      65      F
# 2   3   45     175      80      M
# 3   4   25     165      55      F
# 4   5   36     180      90      M

# %% [markdown]
# 2. Criar um histograma da variável 'age' usando Matplotlib.

# %%
import matplotlib.pyplot as plt

# Criar o histograma
plt.hist(df_saude['age'], bins=20, edgecolor='black')
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.title('Distribuição de Idade')
plt.show()

# %% [markdown]
# 3. Criar um gráfico de dispersão mostrando a relação entre 'height' e 'weight' usando Seaborn.

# %%
import seaborn as sns

# Criar o gráfico de dispersão
sns.scatterplot(x='height', y='weight', data=df_saude)
plt.xlabel('Altura')
plt.ylabel('Peso')
plt.title('Relação entre Altura e Peso')
plt.show()

# %% [markdown]
# 4. Criar um gráfico interativo de barras mostrando a contagem de indivíduos por
# 'gender' usando Plotly.

# %%
import plotly.express as px

# Criar o gráfico de barras
fig = px.bar(df_saude, x='gender', title='Contagem de Indivíduos por Gênero')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Desafio Prático 2: Séries Temporais**
#
# **Descrição:** Neste desafio, suas alunas irão analisar uma série temporal de dados de vendas. Elas deverão criar gráficos que mostrem as vendas ao longo do tempo, identificar tendências e sazonalidades.
#
# **Tarefas:**

# %% [markdown]
# 1. Carregar os dados de um arquivo CSV fornecido (vendas.csv).

# %%
import pandas as pd

# Carregar o arquivo CSV
df_vendas = pd.read_csv('/content/drive/MyDrive/vendas.csv')

# Verificar as primeiras linhas do DataFrame
print(df_vendas.head())
# Out:
#          date  sales
# 0  2023-01-01    100
# 1  2023-01-02    150
# 2  2023-01-03    200
# 3  2023-01-04    130
# 4  2023-01-05    180

# %%
df_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    31 non-null     object
#  1   sales   31 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 624.0+ bytes

# %% [markdown]
# 2. Criar um gráfico de linhas das vendas ao longo do tempo usando Matplotlib.

# %%
plt.plot(df_vendas['date'], df_vendas['sales'])
plt.xlabel('Data')
plt.ylabel('Vendas')
plt.title('Vendas ao Longo do Tempo')
plt.xticks(df_vendas['date'][::2]) # Mostra uma data a cada 2 dias
plt.xticks(rotation=45, ha='right')  # Rotaciona os rótulos em 45 graus
plt.tight_layout  # Ajusta o layout para evitar sobreposição
plt.show()

# %% [markdown]
# 3. Criar um gráfico de decomposição sazonal usando Seaborn.

# %%
sns.set(style='whitegrid')
sns.lineplot(x='date', y='sales', data=df_vendas)
plt.xlabel('Data')
plt.ylabel('Vendas')
plt.title('Decomposição Sazonal das Vendas')
plt.xticks(df_vendas['date'][::2]) # Mostra uma data a cada 2 dias
plt.xticks(rotation=45, ha='right')  # Rotaciona os rótulos em 45 graus
plt.tight_layout  # Ajusta o layout para evitar sobreposição
plt.show()

# %% [markdown]
# 4. Criar um gráfico interativo que permita a exploração dos dados de vendas ao longo do tempo usando Plotly

# %%
fig = px.line(df_vendas, x='date', y='sales', title='Vendas ao Longo do Tempo')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
